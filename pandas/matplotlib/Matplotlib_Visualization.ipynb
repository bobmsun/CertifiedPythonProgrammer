# %% [markdown]
# This notebook is along with the video: https://www.youtube.com/watch?v=2ywUfs0rgtU
#
# ### Visualize
#
# * Learn to use Matplotlib
# * Subplots
# * Multiple plots
# * Bar plots

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data = pd.read_csv('../data/AAPL.csv', index_col=0, parse_dates=True)

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2018-03-01  44.634998  44.945000  43.165001  43.750000  41.707802  195208000
# 2018-03-02  43.200001  44.075001  43.112499  44.052502  41.996174  153816000
# 2018-03-05  43.802502  44.435001  43.630001  44.205002  42.141563  113605600
# 2018-03-06  44.477501  44.562500  44.032501  44.167500  42.105808   95154000
# 2018-03-07  43.735001  43.962502  43.567501  43.757500  41.714939  126814000

# %%
data.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
data['Close'].plot()    # You see nothing, because it actually prints it again on the plot above

# How can we deal with it? 
# This is why we need to learn matplotlib in the object-oriented way (below)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Subplots

# %%
fig, ax = plt.subplots()      # what subplots() does is it actually makes a new figure for you
# Now you have the figure and axis

data['Close'].plot(ax=ax)
ax.set_ylabel('Price')
ax.set_title('AAPL')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'AAPL')

# %% [markdown]
# ## Multiple Plots

# %%
# How to make multiple charts in a same figure
fig, ax = plt.subplots(2,2)
data['Open'].plot(ax=ax[0, 0])
data['High'].plot(ax=ax[0, 1])
data['Low'].plot(ax=ax[1, 0])
data['Close'].plot(ax=ax[1, 1])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots(2,2)
data['Open'].plot(ax=ax[0, 0], title='Open')
data['High'].plot(ax=ax[0, 1], title='High')
data['Low'].plot(ax=ax[1, 0], title='Low')
data['Close'].plot(ax=ax[1, 1], title='Close')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Bar Plots

# %%
fig, ax = plt.subplots()
data['Volume'].plot.bar(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots()
data['Volume'].loc['2020-07-01':'2020-08-15'].plot.bar(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
# Horizontal bar chart
fig, ax = plt.subplots()
data['Volume'].loc['2020-07-01':'2020-08-15'].plot.barh(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:ylabel='Date'>
